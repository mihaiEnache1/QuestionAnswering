# %% [markdown]
# <a href="https://colab.research.google.com/github/mihaiEnache1/QuestionAnswering/blob/main/Movie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 20.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.4 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

raw_datasets = load_dataset("wiki_movies")
raw_datasets
# Out:
# ...
# Generating validation split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset wiki_movies downloaded and prepared to /root/.cache/huggingface/datasets/wiki_movies/default/1.1.0/2fab0fed49fad4c5854fcf8d4e958439d961e0d7de5d5ed2ca9ce54e309347cd. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'answer'],
#         num_rows: 96185
#     })
#     test: Dataset({
#         features: ['question', 'answer'],
#         num_rows: 9952
#     })
#     validation: Dataset({
#         features: ['question', 'answer'],
#         num_rows: 10000
#     })
# })

# %%
raw_train_dataset = raw_datasets["train"]
raw_train_dataset[0]
# Out:
# {'question': ' what movies are about ginger rogers?',
#  'answer': 'Top Hat, Kitty Foyle, The Barkleys of Broadway\n'}

# %%
raw_train_dataset.features
# Out:
# {'question': Value(dtype='string', id=None),
#  'answer': Value(dtype='string', id=None)}
